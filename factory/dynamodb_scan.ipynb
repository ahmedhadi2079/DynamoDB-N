# %%
import os
import sys
import base64
import json
import boto3
from botocore.exceptions import ClientError
import requests
import pandas as pd
from datetime import datetime, timedelta
from flatten_json import flatten

sys.path.append(os.path.abspath("../"))
from src.common.dynamo_custom_functions import apply_schema
from src.common.dynamo_custom_functions import get_actual_dtypes

# %%
# aws sso login --profile beta
os.environ.setdefault("AWS_PROFILE", "prod")
session = boto3.Session(profile_name="prod")

# %%
def scan_dynamodb_table(table: str, columns: list = None) -> list:
    """
    Scans a DynamoDB table and retrieves only the specified columns.
    If no columns are specified, retrieves all columns.

    Args:
        table (str): The name of the DynamoDB table to scan.
        columns (list, optional): A list of column names (attributes) to retrieve in the scan.
                                  If None or empty, retrieves all columns.

    Returns:
        list: A list of items retrieved from the table, each containing only the specified columns,
              or all columns if none are specified.
    """
    client = boto3.client("dynamodb")

    scan_kwargs = {"TableName": table}

    if columns:
        # Define placeholders for reserved words in columns
        expression_attribute_names = {}
        projection_expression = []

        # Iterate through columns and replace any reserved keywords
        for column in columns:
            if column.lower() in [
                "name",
                "date",
                "value",
                "type",
                "year",
            ]:  # Add more reserved keywords as needed
                placeholder = f"#{column}"
                expression_attribute_names[placeholder] = column
                projection_expression.append(placeholder)
            else:
                projection_expression.append(column)

        scan_kwargs["ProjectionExpression"] = ",".join(projection_expression)
        if expression_attribute_names:
            scan_kwargs["ExpressionAttributeNames"] = expression_attribute_names

    data = []
    done = False
    start_key = None

    while not done:
        if start_key:
            scan_kwargs["ExclusiveStartKey"] = start_key

        print(f"Scanning DynamoDB table: {table}")

        response = client.scan(**scan_kwargs)
        data.extend(response.get("Items", []))  # Append items to data list

        # Check if there's more data to scan
        start_key = response.get("LastEvaluatedKey")
        done = start_key is None

    return data

# %%
def scan_dynamodb_table_two_days_ago(table: str, columns: list = None) -> list:
    """
    Scans a DynamoDB table and retrieves only the specified columns.
    If no columns are specified, retrieves all columns.
    Filters the results to get only the items updated in the last two days.

    Args:
        table (str): The name of the DynamoDB table to scan.
        columns (list, optional): A list of column names (attributes) to retrieve in the scan.
                                  If None or empty, retrieves all columns.

    Returns:
        list: A list of items retrieved from the table, each containing only the specified columns,
              or all columns if none are specified.
    """
    client = boto3.client("dynamodb")

    # Calculate the timestamp for two days ago
    two_days_ago = datetime.utcnow() - timedelta(days=2)
    two_days_ago_iso = two_days_ago.strftime("%Y-%m-%dT%H:%M:%SZ")

    scan_kwargs = {
        "TableName": table,
        "FilterExpression": "updatedAt >= :two_days_ago",
        "ExpressionAttributeValues": {":two_days_ago": {"S": two_days_ago_iso}},
    }

    if columns:
        # Define placeholders for reserved words in columns
        expression_attribute_names = {}
        projection_expression = []

        # Iterate through columns and replace any reserved keywords
        for column in columns:
            if column.lower() in [
                "name",
                "date",
                "value",
                "type",
                "year",
            ]:  # Add more reserved keywords as needed
                placeholder = f"#{column}"
                expression_attribute_names[placeholder] = column
                projection_expression.append(placeholder)
            else:
                projection_expression.append(column)

        scan_kwargs["ProjectionExpression"] = ",".join(projection_expression)
        if expression_attribute_names:
            scan_kwargs["ExpressionAttributeNames"] = expression_attribute_names

    data = []
    done = False
    start_key = None

    while not done:
        if start_key:
            scan_kwargs["ExclusiveStartKey"] = start_key

        print(f"Scanning DynamoDB table: {table}")

        response = client.scan(**scan_kwargs)
        data.extend(response.get("Items", []))  # Append items to data list

        # Check if there's more data to scan
        start_key = response.get("LastEvaluatedKey")
        done = start_key is None

    return data

# %%
def convert_to_dataframe(data):
    # Helper function to extract the actual value based on the key type
    def extract_value(d):
        if "S" in d:
            return d["S"]
        elif "N" in d:
            return float(d["N"])  # Convert numeric values to float
        elif "BOOL" in d:
            return d["BOOL"]
        return None  # Handle unexpected cases

    # Transform the list of records into a format suitable for DataFrame
    transformed_data = []
    for record in data:
        transformed_record = {
            key: extract_value(value) for key, value in record.items()
        }
        transformed_data.append(transformed_record)

    # Convert the transformed data to a DataFrame
    df = pd.DataFrame(transformed_data)
    return df

# %%
# Define a function to safely convert the timestamp
def safe_convert_timestamp(x):
    try:
        # Convert to datetime if within a reasonable range
        if 0 < x < 4102444800:  # This is up to year 2100
            return datetime.fromtimestamp(x).strftime("%Y-%m-%d")
        else:
            return None  # Return None for out-of-range values
    except Exception:
        return None

# final_df["updated_at"] = final_df["updated_at"] / 1000
# # Apply the conversion function
# final_df["updated_at"] = final_df["updated_at"].apply(safe_convert_timestamp)

# print(final_df["updated_at"])

# %%
data = scan_dynamodb_table(
    "sls-ddb-investments-sell"
)
data
# Out:
# Scanning DynamoDB table: sls-ddb-investments-sell
# [{'encodedKey': {'S': '8a5e2d14836856a4018369873b2802e0'},
#   'providerAccountId': {'S': '2'},
#   'expectedSettlementDate': {'S': '2023-03-15T00:24:56.957Z'},
#   'orderedAt': {'S': '2023-03-05T00:24:56.957Z'},
#   'orderId': {'S': '21D94940E277F5282'},
#   'status': {'S': 'AwaitingOrderConfirmation'},
#   'tenantId': {'S': 'nomo'},
#   'trace': {'L': [{'S': 'PlaceOrderCreated'},
#     {'S': 'AllFundsAccountCreated'},
#     {'S': 'PlaceOrderSuccess'},
#     {'S': 'AwaitingOrderConfirmation'}]},
#   'createdAt': {'N': '1677975896975'},
#   'pricePerShareOnSell': {'M': {'value': {'N': '134.736577'},
#     'currency': {'S': 'USD'}}},
#   'providerSellId': {'S': '29'},
#   'updatedAt': {'N': '1677975900474'},
#   'userId': {'S': 'w1bzb16fXndSPP1iKMDJNc'},
#   'amount': {'M': {'value': {'N': '0'}, 'currency': {'S': 'USD'}}},
#   'provider': {'S': 'allFunds'},
#   'providerInvestmentId': {'S': '218413'},
#   'id': {'S': '0ee43b7f-0405-45b6-bf73-d2b7f4c8ef7f'},
#   'traceId': {'S': 'deec6923-27ca-4aa9-9c29-7c7109ff1096'},
#   'shares': {'N': '0.036881'}},
#  {'encodedKey': {'S': '8a5e019f8362c19901836986433407d1'},
#   'providerAccountId': {'S': '2'},
#   'orderedAt': {'S': '2022-11-24T13:40:03.679Z'},
#   'orderId': {'S': '54FEA8B546B4D4380'},
#   'status': {'S': 'Settled'},
#   'tenantId': {'S': 'nomo'},
#   'trace': {'L': [{'S': 'PlaceOrderCreated'},
#     {'S': 'AllFundsAccountCreated'},
#     {'S': 'PlaceOrderSuccess'},
#     {'S': 'AwaitingOrderConfirmation'}]},
#   'createdAt': {'N': '1669297203680'},
#   'settlementDate': {'S': '2022-11-27T13:40:03.679Z'},
#   'settlementShares': {'N': '0.1'},
#   'pricePerShareOnSell': {'M': {'value': {'N': '12'},
#     'currency': {'S': 'GBP'}}},
#   'providerSellId': {'S': '6'},
#   'updatedAt': {'N': '1669297205900'},
#   'userId': {'S': 'w1bzb16fXndSPP1iKMDJNc'},
#   'amount': {'M': {'value': {'N': '0'}, 'currency': {'S': 'GBP'}}},
#   'provider': {'S': 'allFunds'},
#   'providerInvestmentId': {'S': '289627'},
#   'id': {'S': '8ba1ab6f-e39a-4049-990b-e49ff607d903'},
#   'traceId': {'S': 'GBP-sell-order'},
#   'shares': {'N': '0.1'}},
#  {'encodedKey': {'S': '8a5e0f738b887a74018b8bc9d11a01f5'},
#   'providerAccountId': {'S': '11'},
#   'expectedSettlementDate': {'S': '2024-10-18T11:27:51.709Z'},
#   'orderedAt': {'S': '2024-10-08T11:27:51.709Z'},
#   'orderId': {'S': 'F2DCAA61DF026A04E'},
#   'status': {'S': 'AwaitingOrderConfirmation'},
#   'tenantId': {'S': 'nomo'},
#   'trace': {'L': [{'M': {'createdAt': {'S': '2024-10-08T11:27:51.709Z'},
#       'status': {'S': 'PlaceOrderCreated'}}},
#     {'M': {'createdAt': {'S': '2024-10-08T11:27:52.728Z'},
#       'status': {'S': 'AllFundsAccountCreated'}}},
#     {'M': {'createdAt': {'S': '2024-10-08T11:27:54.257Z'},
#       'status': {'S': 'PlaceOrderSuccess'}}},
#     {'M': {'createdAt': {'S': '2024-10-08T11:27:54.601Z'},
#       'status': {'S': 'AwaitingOrderConfirmation'}}}]},
#   'createdAt': {'N': '1728386871719'},
#   'investmentName': {'S': 'OASIS CRESCENT GLOBAL SHORT TERM INCOME "F" (GBP) INC'},
#   'pricePerShareOnSell': {'M': {'value': {'N': '0.7306'},
#     'currency': {'S': 'GBP'}}},
#   'providerSellId': {'S': '138'},
#   'updatedAt': {'N': '1728386874619'},
#   'userId': {'S': 'usRJYMwWkErLrmQLcqg7o6'},
#   'amount': {'M': {'value': {'N': '0'}, 'currency': {'S': 'GBP'}}},
#   'provider': {'S': 'allFunds'},
#   'providerInvestmentId': {'S': '289648'},
#   'id': {'S': 'b4344e05-9955-418e-aba0-2b12ab1097c2'},
#   'traceId': {'S': '2ca2c85a-5808-4f63-b5d0-19b7c41de5aa'},
#   'shares': {'N': '3.995'}},
#  {'providerAccountId': {'S': '2'},
#   'orderId': {'S': '85EA49B4312AC506A'},
#   'status': {'S': 'Settled'},
#   'tenantId': {'S': 'nomo'},
#   'settlementCurrency': {'S': 'GBP'},
#   'settlementDate': {'S': '2023-05-09'},
#   'settlementShares': {'N': '0.1'},
#   'confirmedAt': {'S': '2023-05-02T18:54:27.734Z'},
#   'investmentName': {'S': 'OASIS CRESCENT GLOBAL MEDIUM EQUITY "D" (GBP) INC'},
#   'pricePerShareOnSell': {'M': {'value': {'N': '16'},
#     'currency': {'S': 'GBP'}}},
#   'providerSellId': {'S': '40'},
#   'userId': {'S': 'w1bzb16fXndSPP1iKMDJNc'},
#   'confirmation': {'M': {'generalOperationData': {'M': {'confirmationDate': {'S': '2023-05-02'},
#       'ccc': {'S': ''},
#       'calculatedCrossAmount': {'N': '1.64'},
#       'secondaryKey': {'S': '0100000001'},
#       'allFundsHouseCommission': {'N': '0'},
#       'portfolioIndicator': {'S': 'N'},
#       'performanceFee': {'N': '0'},
#       'fundCode': {'S': 'GB00BLD0V662'},
#       'cutOffDate': {'S': '2023-04-28'},
#       'price': {'N': '16.4366'},
#       'ccv': {'S': ''},
#       'allFundsFundCode': {'S': '0289627'},
#       'sourceContract': {'S': '46AA703B5FBEC9ECF030'},
#       'fundIdentificationType': {'S': '00'},
#       'subdistributor': {'S': '99999'},
#       'settlementDate': {'S': '2023-05-09'},
#       'operationNumber2': {'S': ''},
#       'fundManagerSettlementDate': {'S': '2023-05-09'},
#       'sequence': {'S': '0000000'},
#       'dataTime': {'S': '203602'},
#       'distributorCommission2': {'N': '0'},
#       'amountToBeSettled': {'N': '1.64'},
#       'deposit': {'N': '0'},
#       'operationType': {'S': '20'},
#       'fundName': {'S': 'OASIS CRESCENT GLOBAL "D" (GBP) D A'},
#       'paymentCurrency': {'S': 'GBP'},
#       'confirmedShares': {'N': '0.1'},
#       'operationDate': {'S': '2023-04-27'},
#       'distributorCode': {'S': '00000'},
#       'distributorCommission1': {'N': '0'},
#       'switchFixing': {'N': '1'},
#       'operationNumber': {'S': '85EA49B4312AC506A'},
#       'currency': {'S': 'GBP'},
#       'corporateActionId': {'S': ''},
#       'allFundsOperationNumber2': {'S': '0000000000000'},
#       'product': {'S': '0000000035862'},
#       'entityCode': {'S': '14146'},
#       'dataDate': {'S': '2023-05-02'},
#       'navDate': {'S': '2023-04-28'},
#       'allFundsOperationNumber': {'S': '0000000000040'},
#       'recordType': {'S': '24'},
#       'recordSubtype': {'S': '01'},
#       'agreedFixingCurrency': {'S': 'GBP'},
#       'calculatedNetAmount': {'N': '1.64'},
#       'counterValue': {'N': '0.8805'},
#       'allFundsContract': {'S': '0000002'},
#       'fundHouseCommission': {'N': '0'},
#       'totalExchangeRate': {'N': '1'},
#       'fundCommission': {'N': '0'},
#       'exchangeIndicator': {'S': 'N'},
#       'primaryKey': {'S': '24141460000000000040'}}}}},
#   'provider': {'S': 'allFunds'},
#   'providerInvestmentId': {'S': '289627'},
#   'id': {'S': 'ac906284-1d0d-4576-ad1c-37e12b678939'},
#   'traceId': {'S': 'SELL-GBP-23-04-27'},
#   'encodedKey': {'S': '8a5e019f8362c19901836986433407d1'},
#   'expectedSettlementDate': {'S': '2023-05-07T14:00:17.304Z'},
#   'orderedAt': {'S': '2023-04-27T14:00:17.304Z'},
#   'settlementAmount': {'N': '1.64'},
#   'trace': {'L': [{'S': 'PlaceOrderCreated'},
#     {'S': 'AllFundsAccountCreated'},
#     {'S': 'PlaceOrderSuccess'},
#     {'S': 'AwaitingOrderConfirmation'},
#     {'S': 'OrderConfirmed'},
#     {'S': 'AwaitingSettlement'}]},
#   'createdAt': {'N': '1682604017307'},
#   'updatedAt': {'N': '1683654933423'},
#   'amount': {'M': {'value': {'N': '0'}, 'currency': {'S': 'GBP'}}},
#   'shares': {'N': '0.1'}},
#  {'encodedKey': {'S': '8a5e09827984889d017984889e9a0007'},
#   'providerAccountId': {'S': '8'},
#   'expectedSettlementDate': {'S': '2024-10-17T11:49:20.919Z'},
#   'orderedAt': {'S': '2024-10-07T11:49:20.918Z'},
#   'orderId': {'S': '880B27902F1CCE115'},
#   'status': {'S': 'AwaitingOrderConfirmation'},
#   'tenantId': {'S': 'nomo'},
#   'trace': {'L': [{'M': {'createdAt': {'S': '2024-10-07T11:49:20.918Z'},
#       'status': {'S': 'PlaceOrderCreated'}}},
#     {'M': {'createdAt': {'S': '2024-10-07T11:49:21.950Z'},
#       'status': {'S': 'AllFundsAccountCreated'}}},
#     {'M': {'createdAt': {'S': '2024-10-07T11:49:23.367Z'},
#       'status': {'S': 'PlaceOrderSuccess'}}},
#     {'M': {'createdAt': {'S': '2024-10-07T11:49:24.016Z'},
#       'status': {'S': 'AwaitingOrderConfirmation'}}}]},
#   'createdAt': {'N': '1728301760936'},
#   'investmentName': {'S': 'BNP PARIBAS ISLAMIC FUND HILAL INCOME "C" (USD) ACC'},
#   'pricePerShareOnSell': {'M': {'value': {'N': '1652.0994'},
#     'currency': {'S': 'USD'}}},
#   'providerSellId': {'S': '136'},
#   'updatedAt': {'N': '1728301764035'},
#   'userId': {'S': '2Twyq4ijDoHUfHQk2wZm6D'},
#   'amount': {'M': {'value': {'N': '0'}, 'currency': {'S': 'USD'}}},
#   'provider': {'S': 'allFunds'},
#   'providerInvestmentId': {'S': '271544'},
#   'id': {'S': '55a2a685-bc1f-4364-b672-98563b5b51f0'},
#   'traceId': {'S': '3c8334b6-2372-46b9-bad7-ffe7e6336a78'},
#   'shares': {'N': '0.006'}},
#  {'providerAccountId': {'S': '9'},
#   'orderId': {'S': 'D8AF89422C3D488E6'},
#   'status': {'S': 'Settled'},
#   'tenantId': {'S': 'nomo'},
#   'settlementCurrency': {'S': 'GBP'},
#   'settlementDate': {'S': '2024-03-12'},
#   'settlementShares': {'N': '0.1'},
#   'confirmedAt': {'S': '2024-03-06T19:40:05.519Z'},
#   'investmentName': {'S': 'OASIS CRESCENT GLOBAL SHORT TERM INCOME "F" (GBP) INC'},
#   'pricePerShareOnSell': {'M': {'value': {'N': '0.7534'},
#     'currency': {'S': 'GBP'}}},
#   'providerSellId': {'S': '89'},
#   'userId': {'S': 'tuYQ63FBaKSPNcPYb9L9bZ'},
#   'confirmation': {'M': {'generalOperationData': {'M': {'confirmationDate': {'S': '2024-03-06'},
#       'ccc': {'S': ''},
#       'calculatedCrossAmount': {'N': '0.07'},
#       'secondaryKey': {'S': '0100000001'},
#       'allFundsHouseCommission': {'N': '0'},
#       'portfolioIndicator': {'S': 'N'},
#       'performanceFee': {'N': '0'},
#       'fundCode': {'S': 'GB00BLD0VQ69'},
#       'cutOffDate': {'S': '2024-03-05'},
#       'price': {'N': '0.7475'},
#       'ccv': {'S': ''},
#       'allFundsFundCode': {'S': '0289648'},
#       'sourceContract': {'S': 'BBD4F0C212D559545E2F'},
#       'fundIdentificationType': {'S': '00'},
#       'subdistributor': {'S': '99999'},
#       'settlementDate': {'S': '2024-03-12'},
#       'operationNumber2': {'S': ''},
#       'fundManagerSettlementDate': {'S': '2024-03-12'},
#       'sequence': {'S': '0000000'},
#       'dataTime': {'S': '202259'},
#       'distributorCommission2': {'N': '0'},
#       'amountToBeSettled': {'N': '0.07'},
#       'deposit': {'N': '0'},
#       'operationType': {'S': '20'},
#       'fundName': {'S': 'OASIS CRESCENT GLOBAL "F" (GBP) D A'},
#       'paymentCurrency': {'S': 'GBP'},
#       'confirmedShares': {'N': '0.1'},
#       'operationDate': {'S': '2024-03-04'},
#       'distributorCode': {'S': '00000'},
#       'distributorCommission1': {'N': '0'},
#       'switchFixing': {'N': '1'},
#       'operationNumber': {'S': 'D8AF89422C3D488E6'},
#       'currency': {'S': 'GBP'},
#       'corporateActionId': {'S': ''},
#       'allFundsOperationNumber2': {'S': '0000000000000'},
#       'product': {'S': '0000000035862'},
#       'entityCode': {'S': '14146'},
#       'dataDate': {'S': '2024-03-06'},
#       'navDate': {'S': '2024-03-05'},
#       'allFundsOperationNumber': {'S': '0000000000089'},
#       'recordType': {'S': '24'},
#       'recordSubtype': {'S': '01'},
#       'agreedFixingCurrency': {'S': 'GBP'},
#       'calculatedNetAmount': {'N': '0.07'},
#       'counterValue': {'N': '0.85543'},
#       'allFundsContract': {'S': '0000009'},
#       'fundHouseCommission': {'N': '0'},
#       'totalExchangeRate': {'N': '1'},
#       'fundCommission': {'N': '0'},
#       'exchangeIndicator': {'S': 'N'},
#       'primaryKey': {'S': '24141460000000000089'}}}}},
#   'provider': {'S': 'allFunds'},
#   'providerInvestmentId': {'S': '289648'},
#   'id': {'S': '6e7f8f8c-cdec-4dfb-aa59-b12328f0c67a'},
#   'traceId': {'S': 'SELL-GBP-2024-03-04-tuYQ63FBaKSPNcPYb9L9bZ'},
#   'encodedKey': {'S': '8a5e23ac884b5cb401884ce04e9815da'},
#   'expectedSettlementDate': {'S': '2024-03-14T13:47:49.015Z'},
#   'orderedAt': {'S': '2024-03-04T13:47:49.015Z'},
#   'settlementAmount': {'N': '0.07'},
#   'trace': {'L': [{'S': 'PlaceOrderCreated'},
#     {'S': 'AllFundsAccountCreated'},
#     {'S': 'PlaceOrderSuccess'},
#     {'S': 'AwaitingOrderConfirmation'},
#     {'S': 'OrderConfirmed'},
#     {'S': 'AwaitingSettlement'}]},
#   'createdAt': {'N': '1709560069018'},
#   'updatedAt': {'N': '1710268879814'},
#   'amount': {'M': {'value': {'N': '0'}, 'currency': {'S': 'GBP'}}},
#   'shares': {'N': '0.1'}},
#  {'providerAccountId': {'S': '2'},
#   'orderId': {'S': '8D63463B141E6B0F2'},
#   'status': {'S': 'Settled'},
#   'tenantId': {'S': 'nomo'},
#   'settlementCurrency': {'S': 'USD'},
#   'settlementDate': {'S': '2023-05-26'},
#   'settlementShares': {'N': '0.007317'},
#   'confirmedAt': {'S': '2023-05-23T19:01:58.660Z'},
#   'investmentName': {'S': 'RASMALA GLOBAL SUKUK "A" (USD) ACC'},
#   'pricePerShareOnSell': {'M': {'value': {'N': '1570'},
#     'currency': {'S': 'USD'}}},
#   'providerSellId': {'S': '43'},
#   'userId': {'S': 'w1bzb16fXndSPP1iKMDJNc'},
#   'confirmation': {'M': {'generalOperationData': {'M': {'confirmationDate': {'S': '2023-05-23'},
#       'ccc': {'S': ''},
#       'calculatedCrossAmount': {'N': '1'},
#       'secondaryKey': {'S': '0100000001'},
#       'allFundsHouseCommission': {'N': '0'},
#       'portfolioIndicator': {'S': 'N'},
#       'performanceFee': {'N': '0'},
#       'fundCode': {'S': 'LU1039522393'},
#       'cutOffDate': {'S': '2023-05-19'},
#       'price': {'N': '136.870082'},
#       'ccv': {'S': ''},
#       'allFundsFundCode': {'S': '0218413'},
#       'sourceContract': {'S': '46AA703B5FBEC9ECF030'},
#       'fundIdentificationType': {'S': '00'},
#       'subdistributor': {'S': '99999'},
#       'settlementDate': {'S': '2023-05-26'},
#       'operationNumber2': {'S': ''},
#       'fundManagerSettlementDate': {'S': '2023-05-26'},
#       'sequence': {'S': '0000000'},
#       'dataTime': {'S': '203049'},
#       'distributorCommission2': {'N': '0'},
#       'amountToBeSettled': {'N': '1'},
#       'deposit': {'N': '0'},
#       'operationType': {'S': '20'},
#       'fundName': {'S': 'RASMALA GLOBAL SU "A" (USD)'},
#       'paymentCurrency': {'S': 'USD'},
#       'confirmedShares': {'N': '0.007317'},
#       'operationDate': {'S': '2023-05-17'},
#       'distributorCode': {'S': '00000'},
#       'distributorCommission1': {'N': '0'},
#       'switchFixing': {'N': '1'},
#       'operationNumber': {'S': '8D63463B141E6B0F2'},
#       'currency': {'S': 'USD'},
#       'corporateActionId': {'S': ''},
#       'allFundsOperationNumber2': {'S': '0000000000000'},
#       'product': {'S': '0000000035862'},
#       'entityCode': {'S': '14146'},
#       'dataDate': {'S': '2023-05-23'},
#       'navDate': {'S': '2023-05-22'},
#       'allFundsOperationNumber': {'S': '0000000000043'},
#       'recordType': {'S': '24'},
#       'recordSubtype': {'S': '01'},
#       'agreedFixingCurrency': {'S': 'USD'},
#       'calculatedNetAmount': {'N': '1'},
#       'counterValue': {'N': '1.0822'},
#       'allFundsContract': {'S': '0000002'},
#       'fundHouseCommission': {'N': '0'},
#       'totalExchangeRate': {'N': '1'},
#       'fundCommission': {'N': '0'},
#       'exchangeIndicator': {'S': 'N'},
#       'primaryKey': {'S': '24141460000000000043'}}}}},
#   'provider': {'S': 'allFunds'},
#   'providerInvestmentId': {'S': '218413'},
#   'id': {'S': 'ef9dd8bc-1117-4758-98cb-6f9a7b818a70'},
#   'traceId': {'S': 'SELL-USD-23-05-17'},
#   'encodedKey': {'S': '8a5e2d14836856a4018369873b2802e0'},
#   'expectedSettlementDate': {'S': '2023-05-27T11:24:51.473Z'},
#   'orderedAt': {'S': '2023-05-17T11:24:51.472Z'},
#   'settlementAmount': {'N': '1'},
#   'trace': {'L': [{'S': 'PlaceOrderCreated'},
#     {'S': 'AllFundsAccountCreated'},
#     {'S': 'PlaceOrderSuccess'},
#     {'S': 'AwaitingOrderConfirmation'},
#     {'S': 'OrderConfirmed'},
#     {'S': 'AwaitingSettlement'}]},
#   'createdAt': {'N': '1684322691476'},
#   'updatedAt': {'N': '1685451804377'},
#   'amount': {'M': {'value': {'N': '0'}, 'currency': {'S': 'USD'}}},
#   'shares': {'N': '0.007317'}},
#  {'encodedKey': {'S': '8a5e019f8362c19901836986433407d1'},
#   'providerAccountId': {'S': '2'},
#   'orderedAt': {'S': '2022-12-02T09:39:17.121Z'},
#   'orderId': {'S': 'D360492CF119756AA'},
#   'status': {'S': 'Settled'},
#   'tenantId': {'S': 'nomo'},
#   'trace': {'L': [{'S': 'PlaceOrderCreated'},
#     {'S': 'AllFundsAccountCreated'},
#     {'S': 'PlaceOrderSuccess'},
#     {'S': 'AwaitingOrderConfirmation'}]},
#   'createdAt': {'N': '1669973957122'},
#   'settlementDate': {'S': '2022-12-02T09:40:03.679Z'},
#   'settlementShares': {'N': '0.1'},
#   'pricePerShareOnSell': {'M': {'value': {'N': '12'},
#     'currency': {'S': 'GBP'}}},
#   'providerSellId': {'S': '7'},
#   'updatedAt': {'N': '1669975364029'},
#   'userId': {'S': 'w1bzb16fXndSPP1iKMDJNc'},
#   'amount': {'M': {'value': {'N': '1'}, 'currency': {'S': 'GBP'}}},
#   'provider': {'S': 'allFunds'},
#   'providerInvestmentId': {'S': '289627'},
#   'id': {'S': 'cc14167e-98ce-48de-82de-e3c99537a69b'},
#   'traceId': {'S': 'GBP-sell-order-2'},
#   'shares': {'N': '0.1'}},
#  {'encodedKey': {'S': '8a5e019f8362c19901836986433407d1'},
#   'providerAccountId': {'S': '2'},
#   'expectedSettlementDate': {'S': '2023-03-15T00:26:42.958Z'},
#   'orderedAt': {'S': '2023-03-05T00:26:42.958Z'},
#   'orderId': {'S': 'B8DBA6DD78CA76C6B'},
#   'status': {'S': 'AwaitingSettlement'},
#   'tenantId': {'S': 'nomo'},
#   'trace': {'L': [{'S': 'PlaceOrderCreated'},
#     {'S': 'AllFundsAccountCreated'},
#     {'S': 'PlaceOrderSuccess'},
#     {'S': 'AwaitingOrderConfirmation'},
#     {'S': 'OrderConfirmed'},
#     {'S': 'AwaitingSettlement'}]},
#   'createdAt': {'N': '1677976002959'},
#   'settlementDate': {'S': '2023-03-13'},
#   'settlementShares': {'N': '0.296'},
#   'confirmedAt': {'S': '2023-03-17T17:10:18.994Z'},
#   'investmentName': {'S': 'OASIS CRESCENT GLOBAL "D" (GBP) D A'},
#   'pricePerShareOnSell': {'M': {'value': {'N': '16.9783'},
#     'currency': {'S': 'GBP'}}},
#   'providerSellId': {'S': '30'},
#   'userId': {'S': 'w1bzb16fXndSPP1iKMDJNc'},
#   'updatedAt': {'N': '1679073019553'},
#   'confirmation': {'M': {'generalOperationData': {'M': {'confirmationDate': {'S': '2023-03-07'},
#       'calculatedCrossAmount': {'N': '5.02'},
#       'ccc': {'S': ''},
#       'allFundsHouseCommission': {'N': '0'},
#       'secondaryKey': {'S': '0100000001'},
#       'portfolioIndicator': {'S': 'N'},
#       'performanceFee': {'N': '0'},
#       'cutOffDate': {'S': '2023-03-06'},
#       'fundCode': {'S': 'GB00BLD0TQ22'},
#       'price': {'N': '16.9734'},
#       'ccv': {'S': ''},
#       'allFundsFundCode': {'S': '0289628'},
#       'sourceContract': {'S': '46AA703B5FBEC9ECF030'},
#       'fundIdentificationType': {'S': '00'},
#       'subdistributor': {'S': '99999'},
#       'settlementDate': {'S': '2023-03-13'},
#       'operationNumber2': {'S': ''},
#       'fundManagerSettlementDate': {'S': '2023-03-13'},
#       'sequence': {'S': '0000000'},
#       'dataTime': {'S': '201235'},
#       'distributorCommission2': {'N': '0'},
#       'amountToBeSettled': {'N': '5.02'},
#       'deposit': {'N': '0'},
#       'operationType': {'S': '20'},
#       'fundName': {'S': 'OASIS CRESCENT GLOBAL "B" (GBP) D'},
#       'paymentCurrency': {'S': 'GBP'},
#       'confirmedShares': {'N': '0.296'},
#       'operationDate': {'S': '2023-03-05'},
#       'distributorCode': {'S': '00000'},
#       'distributorCommission1': {'N': '0'},
#       'switchFixing': {'N': '1'},
#       'operationNumber': {'S': 'B8DBA6DD78CA76C6B'},
#       'currency': {'S': 'GBP'},
#       'corporateActionId': {'S': ''},
#       'allFundsOperationNumber2': {'S': '0000000000000'},
#       'product': {'S': '0000000035862'},
#       'dataDate': {'S': '2023-03-07'},
#       'entityCode': {'S': '14146'},
#       'navDate': {'S': '2023-03-06'},
#       'allFundsOperationNumber': {'S': '0000000000030'},
#       'agreedFixingCurrency': {'S': 'GBP'},
#       'recordSubtype': {'S': '01'},
#       'recordType': {'S': '24'},
#       'calculatedNetAmount': {'N': '5.02'},
#       'counterValue': {'N': '0.8863'},
#       'allFundsContract': {'S': '0000002'},
#       'fundHouseCommission': {'N': '0'},
#       'totalExchangeRate': {'N': '1'},
#       'exchangeIndicator': {'S': 'N'},
#       'fundCommission': {'N': '0'},
#       'primaryKey': {'S': '24141460000000000030'}}}}},
#   'amount': {'M': {'value': {'N': '5.02'}, 'currency': {'S': 'GBP'}}},
#   'provider': {'S': 'allFunds'},
#   'providerInvestmentId': {'S': '289628'},
#   'id': {'S': '9fb45f80-a4c9-4c98-940c-3c2152671801'},
#   'traceId': {'S': 'deec6923-27ca-4aa9-9c29-7c7109ff1096'},
#   'shares': {'N': '0.296'}},
#  {'providerAccountId': {'S': '3'},
#   'orderId': {'S': '19D82E1693EA83D28'},
#   'status': {'S': 'AwaitingSettlement'},
#   'tenantId': {'S': 'nomo'},
#   'settlementCurrency': {'S': 'GBP'},
#   'settlementDate': {'S': '2024-10-09'},
#   'settlementShares': {'N': '1.503'},
#   'confirmedAt': {'S': '2024-10-03T19:38:21.340Z'},
#   'investmentName': {'S': 'OASIS CRESCENT GLOBAL MEDIUM EQUITY "D" (GBP) INC'},
#   'pricePerShareOnSell': {'M': {'value': {'N': '17.2115'},
#     'currency': {'S': 'GBP'}}},
#   'providerSellId': {'S': '134'},
#   'userId': {'S': '4Cy2MnsdwWWWxbobzaPHPn'},
#   'confirmation': {'M': {'generalOperationData': {'M': {'confirmationDate': {'S': '2024-10-03'},
#       'ccc': {'S': ''},
#       'calculatedCrossAmount': {'N': '25.89'},
#       'secondaryKey': {'S': '0100000001'},
#       'allFundsHouseCommission': {'N': '0'},
#       'portfolioIndicator': {'S': 'N'},
#       'performanceFee': {'N': '0'},
#       'fundCode': {'S': 'GB00BLD0V662'},
#       'cutOffDate': {'S': '2024-10-02'},
#       'price': {'N': '17.2257'},
#       'ccv': {'S': ''},
#       'allFundsFundCode': {'S': '0289627'},
#       'sourceContract': {'S': '4D7D092DD12227E77827'},
#       'fundIdentificationType': {'S': '00'},
#       'subdistributor': {'S': '99999'},
#       'settlementDate': {'S': '2024-10-09'},
#       'operationNumber2': {'S': ''},
#       'fundManagerSettlementDate': {'S': '2024-10-09'},
#       'sequence': {'S': '0000000'},
#       'dataTime': {'S': '211354'},
#       'distributorCommission2': {'N': '0'},
#       'amountToBeSettled': {'N': '25.89'},
#       'deposit': {'N': '0'},
#       'operationType': {'S': '20'},
#       'fundName': {'S': 'OASIS CRESCENT GLOBAL "D" (GBP) D A'},
#       'paymentCurrency': {'S': 'GBP'},
#       'confirmedShares': {'N': '1.503'},
#       'operationDate': {'S': '2024-10-01'},
#       'distributorCode': {'S': '00000'},
#       'distributorCommission1': {'N': '0'},
#       'switchFixing': {'N': '1'},
#       'operationNumber': {'S': '19D82E1693EA83D28'},
#       'currency': {'S': 'GBP'},
#       'corporateActionId': {'S': ''},
#       'allFundsOperationNumber2': {'S': '0000000000000'},
#       'product': {'S': '0000000035862'},
#       'entityCode': {'S': '14146'},
#       'dataDate': {'S': '2024-10-03'},
#       'navDate': {'S': '2024-10-02'},
#       'allFundsOperationNumber': {'S': '0000000000134'},
#       'recordType': {'S': '24'},
#       'recordSubtype': {'S': '01'},
#       'agreedFixingCurrency': {'S': 'GBP'},
#       'calculatedNetAmount': {'N': '25.89'},
#       'counterValue': {'N': '0.83287999'},
#       'allFundsContract': {'S': '0000003'},
#       'fundHouseCommission': {'N': '0'},
#       'totalExchangeRate': {'N': '1'},
#       'fundCommission': {'N': '0'},
#       'exchangeIndicator': {'S': 'N'},
#       'primaryKey': {'S': '24141460000000000134'}}}}},
#   'provider': {'S': 'allFunds'},
#   'providerInvestmentId': {'S': '289627'},
#   'id': {'S': '66ef1970-5cdb-4127-ab43-f7c16c0198a2'},
#   'traceId': {'S': '104817c3-3ddf-488b-8de8-7ddf397b7e92'},
#   'encodedKey': {'S': '8a5e09827984889d017984889e9a0009'},
#   'expectedSettlementDate': {'S': '2024-10-11T17:02:28.465Z'},
#   'orderedAt': {'S': '2024-10-01T17:02:28.465Z'},
#   'settlementAmount': {'N': '25.89'},
#   'trace': {'L': [{'M': {'createdAt': {'S': '2024-10-01T17:02:28.465Z'},
#       'status': {'S': 'PlaceOrderCreated'}}},
#     {'M': {'createdAt': {'S': '2024-10-01T17:02:29.377Z'},
#       'status': {'S': 'AllFundsAccountCreated'}}},
#     {'M': {'createdAt': {'S': '2024-10-01T17:02:30.626Z'},
#       'status': {'S': 'PlaceOrderSuccess'}}},
#     {'M': {'createdAt': {'S': '2024-10-01T17:02:31.165Z'},
#       'status': {'S': 'AwaitingOrderConfirmation'}}},
#     {'M': {'createdAt': {'S': '2024-10-03T19:38:21.340Z'},
#       'status': {'S': 'OrderConfirmed'}}},
#     {'M': {'createdAt': {'S': '2024-10-03T19:38:22.421Z'},
#       'status': {'S': 'AwaitingSettlement'}}}]},
#   'createdAt': {'N': '1727802148467'},
#   'updatedAt': {'N': '1727984302440'},
#   'amount': {'M': {'value': {'N': '0'}, 'currency': {'S': 'GBP'}}},
#   'shares': {'N': '1.503'}},
#  {'providerAccountId': {'S': '2'},
#   'orderId': {'S': 'E7B740879F409EF79'},
#   'status': {'S': 'AwaitingSettlement'},
#   'tenantId': {'S': 'nomo'},
#   'settlementCurrency': {'S': 'USD'},
#   'settlementDate': {'S': '2023-05-05'},
#   'settlementShares': {'N': '0.01'},
#   'confirmedAt': {'S': '2023-05-03T19:14:35.507Z'},
#   'investmentName': {'S': 'BNP PARIBAS ISLAMIC FUND HILAL INCOME "C" (USD) ACC'},
#   'pricePerShareOnSell': {'M': {'value': {'N': '1570'},
#     'currency': {'S': 'GBP'}}},
#   'providerSellId': {'S': '41'},
#   'userId': {'S': 'w1bzb16fXndSPP1iKMDJNc'},
#   'confirmation': {'M': {'generalOperationData': {'M': {'confirmationDate': {'S': '2023-05-03'},
#       'ccc': {'S': ''},
#       'calculatedCrossAmount': {'N': '15.68'},
#       'secondaryKey': {'S': '0100000001'},
#       'allFundsHouseCommission': {'N': '0'},
#       'portfolioIndicator': {'S': 'N'},
#       'performanceFee': {'N': '0'},
#       'fundCode': {'S': 'LU1150255971'},
#       'cutOffDate': {'S': '2023-04-28'},
#       'price': {'N': '1567.7417'},
#       'ccv': {'S': ''},
#       'allFundsFundCode': {'S': '0271544'},
#       'sourceContract': {'S': '46AA703B5FBEC9ECF030'},
#       'fundIdentificationType': {'S': '00'},
#       'subdistributor': {'S': '99999'},
#       'settlementDate': {'S': '2023-05-05'},
#       'operationNumber2': {'S': ''},
#       'fundManagerSettlementDate': {'S': '2023-05-05'},
#       'sequence': {'S': '0000000'},
#       'dataTime': {'S': '203721'},
#       'distributorCommission2': {'N': '0'},
#       'amountToBeSettled': {'N': '15.68'},
#       'deposit': {'N': '0'},
#       'operationType': {'S': '20'},
#       'fundName': {'S': 'BNP PARIBAS ISLAMIC F HILAL INC "C"(USD)'},
#       'paymentCurrency': {'S': 'USD'},
#       'confirmedShares': {'N': '0.01'},
#       'operationDate': {'S': '2023-04-27'},
#       'distributorCode': {'S': '00000'},
#       'distributorCommission1': {'N': '0'},
#       'switchFixing': {'N': '1'},
#       'operationNumber': {'S': 'E7B740879F409EF79'},
#       'currency': {'S': 'USD'},
#       'corporateActionId': {'S': ''},
#       'allFundsOperationNumber2': {'S': '0000000000000'},
#       'product': {'S': '0000000035862'},
#       'entityCode': {'S': '14146'},
#       'dataDate': {'S': '2023-05-03'},
#       'navDate': {'S': '2023-05-02'},
#       'allFundsOperationNumber': {'S': '0000000000041'},
#       'recordType': {'S': '24'},
#       'recordSubtype': {'S': '01'},
#       'agreedFixingCurrency': {'S': 'USD'},
#       'calculatedNetAmount': {'N': '15.68'},
#       'counterValue': {'N': '1.0965'},
#       'allFundsContract': {'S': '0000002'},
#       'fundHouseCommission': {'N': '0'},
#       'totalExchangeRate': {'N': '1'},
#       'fundCommission': {'N': '0'},
#       'exchangeIndicator': {'S': 'N'},
#       'primaryKey': {'S': '24141460000000000041'}}}}},
#   'provider': {'S': 'allFunds'},
#   'providerInvestmentId': {'S': '271544'},
#   'id': {'S': '0fb710e3-2ddd-492e-8918-410e8da5b235'},
#   'traceId': {'S': 'SELL-USD-23-04-27'},
#   'encodedKey': {'S': '8a5e2d14836856a4018369873b2802e0'},
#   'expectedSettlementDate': {'S': '2023-05-07T14:21:33.069Z'},
#   'orderedAt': {'S': '2023-04-27T14:21:33.068Z'},
#   'settlementAmount': {'N': '15.68'},
#   'trace': {'L': [{'S': 'PlaceOrderCreated'},
#     {'S': 'AllFundsAccountCreated'},
#     {'S': 'PlaceOrderSuccess'},
#     {'S': 'AwaitingOrderConfirmation'},
#     {'S': 'OrderConfirmed'},
#     {'S': 'AwaitingSettlement'}]},
#   'createdAt': {'N': '1682605293071'},
#   'updatedAt': {'N': '1683141276163'},
#   'amount': {'M': {'value': {'N': '0'}, 'currency': {'S': 'GBP'}}},
#   'shares': {'N': '0.01'}}]

# %%
frames = []
for record in data:
    flat_json = flatten(record)
    frames.append(flat_json)

# %%
frames
# Out:
# [{'encodedKey_S': '8a5e2d14836856a4018369873b2802e0',
#   'providerAccountId_S': '2',
#   'expectedSettlementDate_S': '2023-03-15T00:24:56.957Z',
#   'orderedAt_S': '2023-03-05T00:24:56.957Z',
#   'orderId_S': '21D94940E277F5282',
#   'status_S': 'AwaitingOrderConfirmation',
#   'tenantId_S': 'nomo',
#   'trace_L_0_S': 'PlaceOrderCreated',
#   'trace_L_1_S': 'AllFundsAccountCreated',
#   'trace_L_2_S': 'PlaceOrderSuccess',
#   'trace_L_3_S': 'AwaitingOrderConfirmation',
#   'createdAt_N': '1677975896975',
#   'pricePerShareOnSell_M_value_N': '134.736577',
#   'pricePerShareOnSell_M_currency_S': 'USD',
#   'providerSellId_S': '29',
#   'updatedAt_N': '1677975900474',
#   'userId_S': 'w1bzb16fXndSPP1iKMDJNc',
#   'amount_M_value_N': '0',
#   'amount_M_currency_S': 'USD',
#   'provider_S': 'allFunds',
#   'providerInvestmentId_S': '218413',
#   'id_S': '0ee43b7f-0405-45b6-bf73-d2b7f4c8ef7f',
#   'traceId_S': 'deec6923-27ca-4aa9-9c29-7c7109ff1096',
#   'shares_N': '0.036881'},
#  {'encodedKey_S': '8a5e019f8362c19901836986433407d1',
#   'providerAccountId_S': '2',
#   'orderedAt_S': '2022-11-24T13:40:03.679Z',
#   'orderId_S': '54FEA8B546B4D4380',
#   'status_S': 'Settled',
#   'tenantId_S': 'nomo',
#   'trace_L_0_S': 'PlaceOrderCreated',
#   'trace_L_1_S': 'AllFundsAccountCreated',
#   'trace_L_2_S': 'PlaceOrderSuccess',
#   'trace_L_3_S': 'AwaitingOrderConfirmation',
#   'createdAt_N': '1669297203680',
#   'settlementDate_S': '2022-11-27T13:40:03.679Z',
#   'settlementShares_N': '0.1',
#   'pricePerShareOnSell_M_value_N': '12',
#   'pricePerShareOnSell_M_currency_S': 'GBP',
#   'providerSellId_S': '6',
#   'updatedAt_N': '1669297205900',
#   'userId_S': 'w1bzb16fXndSPP1iKMDJNc',
#   'amount_M_value_N': '0',
#   'amount_M_currency_S': 'GBP',
#   'provider_S': 'allFunds',
#   'providerInvestmentId_S': '289627',
#   'id_S': '8ba1ab6f-e39a-4049-990b-e49ff607d903',
#   'traceId_S': 'GBP-sell-order',
#   'shares_N': '0.1'},
#  {'encodedKey_S': '8a5e0f738b887a74018b8bc9d11a01f5',
#   'providerAccountId_S': '11',
#   'expectedSettlementDate_S': '2024-10-18T11:27:51.709Z',
#   'orderedAt_S': '2024-10-08T11:27:51.709Z',
#   'orderId_S': 'F2DCAA61DF026A04E',
#   'status_S': 'AwaitingOrderConfirmation',
#   'tenantId_S': 'nomo',
#   'trace_L_0_M_createdAt_S': '2024-10-08T11:27:51.709Z',
#   'trace_L_0_M_status_S': 'PlaceOrderCreated',
#   'trace_L_1_M_createdAt_S': '2024-10-08T11:27:52.728Z',
#   'trace_L_1_M_status_S': 'AllFundsAccountCreated',
#   'trace_L_2_M_createdAt_S': '2024-10-08T11:27:54.257Z',
#   'trace_L_2_M_status_S': 'PlaceOrderSuccess',
#   'trace_L_3_M_createdAt_S': '2024-10-08T11:27:54.601Z',
#   'trace_L_3_M_status_S': 'AwaitingOrderConfirmation',
#   'createdAt_N': '1728386871719',
#   'investmentName_S': 'OASIS CRESCENT GLOBAL SHORT TERM INCOME "F" (GBP) INC',
#   'pricePerShareOnSell_M_value_N': '0.7306',
#   'pricePerShareOnSell_M_currency_S': 'GBP',
#   'providerSellId_S': '138',
#   'updatedAt_N': '1728386874619',
#   'userId_S': 'usRJYMwWkErLrmQLcqg7o6',
#   'amount_M_value_N': '0',
#   'amount_M_currency_S': 'GBP',
#   'provider_S': 'allFunds',
#   'providerInvestmentId_S': '289648',
#   'id_S': 'b4344e05-9955-418e-aba0-2b12ab1097c2',
#   'traceId_S': '2ca2c85a-5808-4f63-b5d0-19b7c41de5aa',
#   'shares_N': '3.995'},
#  {'providerAccountId_S': '2',
#   'orderId_S': '85EA49B4312AC506A',
#   'status_S': 'Settled',
#   'tenantId_S': 'nomo',
#   'settlementCurrency_S': 'GBP',
#   'settlementDate_S': '2023-05-09',
#   'settlementShares_N': '0.1',
#   'confirmedAt_S': '2023-05-02T18:54:27.734Z',
#   'investmentName_S': 'OASIS CRESCENT GLOBAL MEDIUM EQUITY "D" (GBP) INC',
#   'pricePerShareOnSell_M_value_N': '16',
#   'pricePerShareOnSell_M_currency_S': 'GBP',
#   'providerSellId_S': '40',
#   'userId_S': 'w1bzb16fXndSPP1iKMDJNc',
#   'confirmation_M_generalOperationData_M_confirmationDate_S': '2023-05-02',
#   'confirmation_M_generalOperationData_M_ccc_S': '',
#   'confirmation_M_generalOperationData_M_calculatedCrossAmount_N': '1.64',
#   'confirmation_M_generalOperationData_M_secondaryKey_S': '0100000001',
#   'confirmation_M_generalOperationData_M_allFundsHouseCommission_N': '0',
#   'confirmation_M_generalOperationData_M_portfolioIndicator_S': 'N',
#   'confirmation_M_generalOperationData_M_performanceFee_N': '0',
#   'confirmation_M_generalOperationData_M_fundCode_S': 'GB00BLD0V662',
#   'confirmation_M_generalOperationData_M_cutOffDate_S': '2023-04-28',
#   'confirmation_M_generalOperationData_M_price_N': '16.4366',
#   'confirmation_M_generalOperationData_M_ccv_S': '',
#   'confirmation_M_generalOperationData_M_allFundsFundCode_S': '0289627',
#   'confirmation_M_generalOperationData_M_sourceContract_S': '46AA703B5FBEC9ECF030',
#   'confirmation_M_generalOperationData_M_fundIdentificationType_S': '00',
#   'confirmation_M_generalOperationData_M_subdistributor_S': '99999',
#   'confirmation_M_generalOperationData_M_settlementDate_S': '2023-05-09',
#   'confirmation_M_generalOperationData_M_operationNumber2_S': '',
#   'confirmation_M_generalOperationData_M_fundManagerSettlementDate_S': '2023-05-09',
#   'confirmation_M_generalOperationData_M_sequence_S': '0000000',
#   'confirmation_M_generalOperationData_M_dataTime_S': '203602',
#   'confirmation_M_generalOperationData_M_distributorCommission2_N': '0',
#   'confirmation_M_generalOperationData_M_amountToBeSettled_N': '1.64',
#   'confirmation_M_generalOperationData_M_deposit_N': '0',
#   'confirmation_M_generalOperationData_M_operationType_S': '20',
#   'confirmation_M_generalOperationData_M_fundName_S': 'OASIS CRESCENT GLOBAL "D" (GBP) D A',
#   'confirmation_M_generalOperationData_M_paymentCurrency_S': 'GBP',
#   'confirmation_M_generalOperationData_M_confirmedShares_N': '0.1',
#   'confirmation_M_generalOperationData_M_operationDate_S': '2023-04-27',
#   'confirmation_M_generalOperationData_M_distributorCode_S': '00000',
#   'confirmation_M_generalOperationData_M_distributorCommission1_N': '0',
#   'confirmation_M_generalOperationData_M_switchFixing_N': '1',
#   'confirmation_M_generalOperationData_M_operationNumber_S': '85EA49B4312AC506A',
#   'confirmation_M_generalOperationData_M_currency_S': 'GBP',
#   'confirmation_M_generalOperationData_M_corporateActionId_S': '',
#   'confirmation_M_generalOperationData_M_allFundsOperationNumber2_S': '0000000000000',
#   'confirmation_M_generalOperationData_M_product_S': '0000000035862',
#   'confirmation_M_generalOperationData_M_entityCode_S': '14146',
#   'confirmation_M_generalOperationData_M_dataDate_S': '2023-05-02',
#   'confirmation_M_generalOperationData_M_navDate_S': '2023-04-28',
#   'confirmation_M_generalOperationData_M_allFundsOperationNumber_S': '0000000000040',
#   'confirmation_M_generalOperationData_M_recordType_S': '24',
#   'confirmation_M_generalOperationData_M_recordSubtype_S': '01',
#   'confirmation_M_generalOperationData_M_agreedFixingCurrency_S': 'GBP',
#   'confirmation_M_generalOperationData_M_calculatedNetAmount_N': '1.64',
#   'confirmation_M_generalOperationData_M_counterValue_N': '0.8805',
#   'confirmation_M_generalOperationData_M_allFundsContract_S': '0000002',
#   'confirmation_M_generalOperationData_M_fundHouseCommission_N': '0',
#   'confirmation_M_generalOperationData_M_totalExchangeRate_N': '1',
#   'confirmation_M_generalOperationData_M_fundCommission_N': '0',
#   'confirmation_M_generalOperationData_M_exchangeIndicator_S': 'N',
#   'confirmation_M_generalOperationData_M_primaryKey_S': '24141460000000000040',
#   'provider_S': 'allFunds',
#   'providerInvestmentId_S': '289627',
#   'id_S': 'ac906284-1d0d-4576-ad1c-37e12b678939',
#   'traceId_S': 'SELL-GBP-23-04-27',
#   'encodedKey_S': '8a5e019f8362c19901836986433407d1',
#   'expectedSettlementDate_S': '2023-05-07T14:00:17.304Z',
#   'orderedAt_S': '2023-04-27T14:00:17.304Z',
#   'settlementAmount_N': '1.64',
#   'trace_L_0_S': 'PlaceOrderCreated',
#   'trace_L_1_S': 'AllFundsAccountCreated',
#   'trace_L_2_S': 'PlaceOrderSuccess',
#   'trace_L_3_S': 'AwaitingOrderConfirmation',
#   'trace_L_4_S': 'OrderConfirmed',
#   'trace_L_5_S': 'AwaitingSettlement',
#   'createdAt_N': '1682604017307',
#   'updatedAt_N': '1683654933423',
#   'amount_M_value_N': '0',
#   'amount_M_currency_S': 'GBP',
#   'shares_N': '0.1'},
#  {'encodedKey_S': '8a5e09827984889d017984889e9a0007',
#   'providerAccountId_S': '8',
#   'expectedSettlementDate_S': '2024-10-17T11:49:20.919Z',
#   'orderedAt_S': '2024-10-07T11:49:20.918Z',
#   'orderId_S': '880B27902F1CCE115',
#   'status_S': 'AwaitingOrderConfirmation',
#   'tenantId_S': 'nomo',
#   'trace_L_0_M_createdAt_S': '2024-10-07T11:49:20.918Z',
#   'trace_L_0_M_status_S': 'PlaceOrderCreated',
#   'trace_L_1_M_createdAt_S': '2024-10-07T11:49:21.950Z',
#   'trace_L_1_M_status_S': 'AllFundsAccountCreated',
#   'trace_L_2_M_createdAt_S': '2024-10-07T11:49:23.367Z',
#   'trace_L_2_M_status_S': 'PlaceOrderSuccess',
#   'trace_L_3_M_createdAt_S': '2024-10-07T11:49:24.016Z',
#   'trace_L_3_M_status_S': 'AwaitingOrderConfirmation',
#   'createdAt_N': '1728301760936',
#   'investmentName_S': 'BNP PARIBAS ISLAMIC FUND HILAL INCOME "C" (USD) ACC',
#   'pricePerShareOnSell_M_value_N': '1652.0994',
#   'pricePerShareOnSell_M_currency_S': 'USD',
#   'providerSellId_S': '136',
#   'updatedAt_N': '1728301764035',
#   'userId_S': '2Twyq4ijDoHUfHQk2wZm6D',
#   'amount_M_value_N': '0',
#   'amount_M_currency_S': 'USD',
#   'provider_S': 'allFunds',
#   'providerInvestmentId_S': '271544',
#   'id_S': '55a2a685-bc1f-4364-b672-98563b5b51f0',
#   'traceId_S': '3c8334b6-2372-46b9-bad7-ffe7e6336a78',
#   'shares_N': '0.006'},
#  {'providerAccountId_S': '9',
#   'orderId_S': 'D8AF89422C3D488E6',
#   'status_S': 'Settled',
#   'tenantId_S': 'nomo',
#   'settlementCurrency_S': 'GBP',
#   'settlementDate_S': '2024-03-12',
#   'settlementShares_N': '0.1',
#   'confirmedAt_S': '2024-03-06T19:40:05.519Z',
#   'investmentName_S': 'OASIS CRESCENT GLOBAL SHORT TERM INCOME "F" (GBP) INC',
#   'pricePerShareOnSell_M_value_N': '0.7534',
#   'pricePerShareOnSell_M_currency_S': 'GBP',
#   'providerSellId_S': '89',
#   'userId_S': 'tuYQ63FBaKSPNcPYb9L9bZ',
#   'confirmation_M_generalOperationData_M_confirmationDate_S': '2024-03-06',
#   'confirmation_M_generalOperationData_M_ccc_S': '',
#   'confirmation_M_generalOperationData_M_calculatedCrossAmount_N': '0.07',
#   'confirmation_M_generalOperationData_M_secondaryKey_S': '0100000001',
#   'confirmation_M_generalOperationData_M_allFundsHouseCommission_N': '0',
#   'confirmation_M_generalOperationData_M_portfolioIndicator_S': 'N',
#   'confirmation_M_generalOperationData_M_performanceFee_N': '0',
#   'confirmation_M_generalOperationData_M_fundCode_S': 'GB00BLD0VQ69',
#   'confirmation_M_generalOperationData_M_cutOffDate_S': '2024-03-05',
#   'confirmation_M_generalOperationData_M_price_N': '0.7475',
#   'confirmation_M_generalOperationData_M_ccv_S': '',
#   'confirmation_M_generalOperationData_M_allFundsFundCode_S': '0289648',
#   'confirmation_M_generalOperationData_M_sourceContract_S': 'BBD4F0C212D559545E2F',
#   'confirmation_M_generalOperationData_M_fundIdentificationType_S': '00',
#   'confirmation_M_generalOperationData_M_subdistributor_S': '99999',
#   'confirmation_M_generalOperationData_M_settlementDate_S': '2024-03-12',
#   'confirmation_M_generalOperationData_M_operationNumber2_S': '',
#   'confirmation_M_generalOperationData_M_fundManagerSettlementDate_S': '2024-03-12',
#   'confirmation_M_generalOperationData_M_sequence_S': '0000000',
#   'confirmation_M_generalOperationData_M_dataTime_S': '202259',
#   'confirmation_M_generalOperationData_M_distributorCommission2_N': '0',
#   'confirmation_M_generalOperationData_M_amountToBeSettled_N': '0.07',
#   'confirmation_M_generalOperationData_M_deposit_N': '0',
#   'confirmation_M_generalOperationData_M_operationType_S': '20',
#   'confirmation_M_generalOperationData_M_fundName_S': 'OASIS CRESCENT GLOBAL "F" (GBP) D A',
#   'confirmation_M_generalOperationData_M_paymentCurrency_S': 'GBP',
#   'confirmation_M_generalOperationData_M_confirmedShares_N': '0.1',
#   'confirmation_M_generalOperationData_M_operationDate_S': '2024-03-04',
#   'confirmation_M_generalOperationData_M_distributorCode_S': '00000',
#   'confirmation_M_generalOperationData_M_distributorCommission1_N': '0',
#   'confirmation_M_generalOperationData_M_switchFixing_N': '1',
#   'confirmation_M_generalOperationData_M_operationNumber_S': 'D8AF89422C3D488E6',
#   'confirmation_M_generalOperationData_M_currency_S': 'GBP',
#   'confirmation_M_generalOperationData_M_corporateActionId_S': '',
#   'confirmation_M_generalOperationData_M_allFundsOperationNumber2_S': '0000000000000',
#   'confirmation_M_generalOperationData_M_product_S': '0000000035862',
#   'confirmation_M_generalOperationData_M_entityCode_S': '14146',
#   'confirmation_M_generalOperationData_M_dataDate_S': '2024-03-06',
#   'confirmation_M_generalOperationData_M_navDate_S': '2024-03-05',
#   'confirmation_M_generalOperationData_M_allFundsOperationNumber_S': '0000000000089',
#   'confirmation_M_generalOperationData_M_recordType_S': '24',
#   'confirmation_M_generalOperationData_M_recordSubtype_S': '01',
#   'confirmation_M_generalOperationData_M_agreedFixingCurrency_S': 'GBP',
#   'confirmation_M_generalOperationData_M_calculatedNetAmount_N': '0.07',
#   'confirmation_M_generalOperationData_M_counterValue_N': '0.85543',
#   'confirmation_M_generalOperationData_M_allFundsContract_S': '0000009',
#   'confirmation_M_generalOperationData_M_fundHouseCommission_N': '0',
#   'confirmation_M_generalOperationData_M_totalExchangeRate_N': '1',
#   'confirmation_M_generalOperationData_M_fundCommission_N': '0',
#   'confirmation_M_generalOperationData_M_exchangeIndicator_S': 'N',
#   'confirmation_M_generalOperationData_M_primaryKey_S': '24141460000000000089',
#   'provider_S': 'allFunds',
#   'providerInvestmentId_S': '289648',
#   'id_S': '6e7f8f8c-cdec-4dfb-aa59-b12328f0c67a',
#   'traceId_S': 'SELL-GBP-2024-03-04-tuYQ63FBaKSPNcPYb9L9bZ',
#   'encodedKey_S': '8a5e23ac884b5cb401884ce04e9815da',
#   'expectedSettlementDate_S': '2024-03-14T13:47:49.015Z',
#   'orderedAt_S': '2024-03-04T13:47:49.015Z',
#   'settlementAmount_N': '0.07',
#   'trace_L_0_S': 'PlaceOrderCreated',
#   'trace_L_1_S': 'AllFundsAccountCreated',
#   'trace_L_2_S': 'PlaceOrderSuccess',
#   'trace_L_3_S': 'AwaitingOrderConfirmation',
#   'trace_L_4_S': 'OrderConfirmed',
#   'trace_L_5_S': 'AwaitingSettlement',
#   'createdAt_N': '1709560069018',
#   'updatedAt_N': '1710268879814',
#   'amount_M_value_N': '0',
#   'amount_M_currency_S': 'GBP',
#   'shares_N': '0.1'},
#  {'providerAccountId_S': '2',
#   'orderId_S': '8D63463B141E6B0F2',
#   'status_S': 'Settled',
#   'tenantId_S': 'nomo',
#   'settlementCurrency_S': 'USD',
#   'settlementDate_S': '2023-05-26',
#   'settlementShares_N': '0.007317',
#   'confirmedAt_S': '2023-05-23T19:01:58.660Z',
#   'investmentName_S': 'RASMALA GLOBAL SUKUK "A" (USD) ACC',
#   'pricePerShareOnSell_M_value_N': '1570',
#   'pricePerShareOnSell_M_currency_S': 'USD',
#   'providerSellId_S': '43',
#   'userId_S': 'w1bzb16fXndSPP1iKMDJNc',
#   'confirmation_M_generalOperationData_M_confirmationDate_S': '2023-05-23',
#   'confirmation_M_generalOperationData_M_ccc_S': '',
#   'confirmation_M_generalOperationData_M_calculatedCrossAmount_N': '1',
#   'confirmation_M_generalOperationData_M_secondaryKey_S': '0100000001',
#   'confirmation_M_generalOperationData_M_allFundsHouseCommission_N': '0',
#   'confirmation_M_generalOperationData_M_portfolioIndicator_S': 'N',
#   'confirmation_M_generalOperationData_M_performanceFee_N': '0',
#   'confirmation_M_generalOperationData_M_fundCode_S': 'LU1039522393',
#   'confirmation_M_generalOperationData_M_cutOffDate_S': '2023-05-19',
#   'confirmation_M_generalOperationData_M_price_N': '136.870082',
#   'confirmation_M_generalOperationData_M_ccv_S': '',
#   'confirmation_M_generalOperationData_M_allFundsFundCode_S': '0218413',
#   'confirmation_M_generalOperationData_M_sourceContract_S': '46AA703B5FBEC9ECF030',
#   'confirmation_M_generalOperationData_M_fundIdentificationType_S': '00',
#   'confirmation_M_generalOperationData_M_subdistributor_S': '99999',
#   'confirmation_M_generalOperationData_M_settlementDate_S': '2023-05-26',
#   'confirmation_M_generalOperationData_M_operationNumber2_S': '',
#   'confirmation_M_generalOperationData_M_fundManagerSettlementDate_S': '2023-05-26',
#   'confirmation_M_generalOperationData_M_sequence_S': '0000000',
#   'confirmation_M_generalOperationData_M_dataTime_S': '203049',
#   'confirmation_M_generalOperationData_M_distributorCommission2_N': '0',
#   'confirmation_M_generalOperationData_M_amountToBeSettled_N': '1',
#   'confirmation_M_generalOperationData_M_deposit_N': '0',
#   'confirmation_M_generalOperationData_M_operationType_S': '20',
#   'confirmation_M_generalOperationData_M_fundName_S': 'RASMALA GLOBAL SU "A" (USD)',
#   'confirmation_M_generalOperationData_M_paymentCurrency_S': 'USD',
#   'confirmation_M_generalOperationData_M_confirmedShares_N': '0.007317',
#   'confirmation_M_generalOperationData_M_operationDate_S': '2023-05-17',
#   'confirmation_M_generalOperationData_M_distributorCode_S': '00000',
#   'confirmation_M_generalOperationData_M_distributorCommission1_N': '0',
#   'confirmation_M_generalOperationData_M_switchFixing_N': '1',
#   'confirmation_M_generalOperationData_M_operationNumber_S': '8D63463B141E6B0F2',
#   'confirmation_M_generalOperationData_M_currency_S': 'USD',
#   'confirmation_M_generalOperationData_M_corporateActionId_S': '',
#   'confirmation_M_generalOperationData_M_allFundsOperationNumber2_S': '0000000000000',
#   'confirmation_M_generalOperationData_M_product_S': '0000000035862',
#   'confirmation_M_generalOperationData_M_entityCode_S': '14146',
#   'confirmation_M_generalOperationData_M_dataDate_S': '2023-05-23',
#   'confirmation_M_generalOperationData_M_navDate_S': '2023-05-22',
#   'confirmation_M_generalOperationData_M_allFundsOperationNumber_S': '0000000000043',
#   'confirmation_M_generalOperationData_M_recordType_S': '24',
#   'confirmation_M_generalOperationData_M_recordSubtype_S': '01',
#   'confirmation_M_generalOperationData_M_agreedFixingCurrency_S': 'USD',
#   'confirmation_M_generalOperationData_M_calculatedNetAmount_N': '1',
#   'confirmation_M_generalOperationData_M_counterValue_N': '1.0822',
#   'confirmation_M_generalOperationData_M_allFundsContract_S': '0000002',
#   'confirmation_M_generalOperationData_M_fundHouseCommission_N': '0',
#   'confirmation_M_generalOperationData_M_totalExchangeRate_N': '1',
#   'confirmation_M_generalOperationData_M_fundCommission_N': '0',
#   'confirmation_M_generalOperationData_M_exchangeIndicator_S': 'N',
#   'confirmation_M_generalOperationData_M_primaryKey_S': '24141460000000000043',
#   'provider_S': 'allFunds',
#   'providerInvestmentId_S': '218413',
#   'id_S': 'ef9dd8bc-1117-4758-98cb-6f9a7b818a70',
#   'traceId_S': 'SELL-USD-23-05-17',
#   'encodedKey_S': '8a5e2d14836856a4018369873b2802e0',
#   'expectedSettlementDate_S': '2023-05-27T11:24:51.473Z',
#   'orderedAt_S': '2023-05-17T11:24:51.472Z',
#   'settlementAmount_N': '1',
#   'trace_L_0_S': 'PlaceOrderCreated',
#   'trace_L_1_S': 'AllFundsAccountCreated',
#   'trace_L_2_S': 'PlaceOrderSuccess',
#   'trace_L_3_S': 'AwaitingOrderConfirmation',
#   'trace_L_4_S': 'OrderConfirmed',
#   'trace_L_5_S': 'AwaitingSettlement',
#   'createdAt_N': '1684322691476',
#   'updatedAt_N': '1685451804377',
#   'amount_M_value_N': '0',
#   'amount_M_currency_S': 'USD',
#   'shares_N': '0.007317'},
#  {'encodedKey_S': '8a5e019f8362c19901836986433407d1',
#   'providerAccountId_S': '2',
#   'orderedAt_S': '2022-12-02T09:39:17.121Z',
#   'orderId_S': 'D360492CF119756AA',
#   'status_S': 'Settled',
#   'tenantId_S': 'nomo',
#   'trace_L_0_S': 'PlaceOrderCreated',
#   'trace_L_1_S': 'AllFundsAccountCreated',
#   'trace_L_2_S': 'PlaceOrderSuccess',
#   'trace_L_3_S': 'AwaitingOrderConfirmation',
#   'createdAt_N': '1669973957122',
#   'settlementDate_S': '2022-12-02T09:40:03.679Z',
#   'settlementShares_N': '0.1',
#   'pricePerShareOnSell_M_value_N': '12',
#   'pricePerShareOnSell_M_currency_S': 'GBP',
#   'providerSellId_S': '7',
#   'updatedAt_N': '1669975364029',
#   'userId_S': 'w1bzb16fXndSPP1iKMDJNc',
#   'amount_M_value_N': '1',
#   'amount_M_currency_S': 'GBP',
#   'provider_S': 'allFunds',
#   'providerInvestmentId_S': '289627',
#   'id_S': 'cc14167e-98ce-48de-82de-e3c99537a69b',
#   'traceId_S': 'GBP-sell-order-2',
#   'shares_N': '0.1'},
#  {'encodedKey_S': '8a5e019f8362c19901836986433407d1',
#   'providerAccountId_S': '2',
#   'expectedSettlementDate_S': '2023-03-15T00:26:42.958Z',
#   'orderedAt_S': '2023-03-05T00:26:42.958Z',
#   'orderId_S': 'B8DBA6DD78CA76C6B',
#   'status_S': 'AwaitingSettlement',
#   'tenantId_S': 'nomo',
#   'trace_L_0_S': 'PlaceOrderCreated',
#   'trace_L_1_S': 'AllFundsAccountCreated',
#   'trace_L_2_S': 'PlaceOrderSuccess',
#   'trace_L_3_S': 'AwaitingOrderConfirmation',
#   'trace_L_4_S': 'OrderConfirmed',
#   'trace_L_5_S': 'AwaitingSettlement',
#   'createdAt_N': '1677976002959',
#   'settlementDate_S': '2023-03-13',
#   'settlementShares_N': '0.296',
#   'confirmedAt_S': '2023-03-17T17:10:18.994Z',
#   'investmentName_S': 'OASIS CRESCENT GLOBAL "D" (GBP) D A',
#   'pricePerShareOnSell_M_value_N': '16.9783',
#   'pricePerShareOnSell_M_currency_S': 'GBP',
#   'providerSellId_S': '30',
#   'userId_S': 'w1bzb16fXndSPP1iKMDJNc',
#   'updatedAt_N': '1679073019553',
#   'confirmation_M_generalOperationData_M_confirmationDate_S': '2023-03-07',
#   'confirmation_M_generalOperationData_M_calculatedCrossAmount_N': '5.02',
#   'confirmation_M_generalOperationData_M_ccc_S': '',
#   'confirmation_M_generalOperationData_M_allFundsHouseCommission_N': '0',
#   'confirmation_M_generalOperationData_M_secondaryKey_S': '0100000001',
#   'confirmation_M_generalOperationData_M_portfolioIndicator_S': 'N',
#   'confirmation_M_generalOperationData_M_performanceFee_N': '0',
#   'confirmation_M_generalOperationData_M_cutOffDate_S': '2023-03-06',
#   'confirmation_M_generalOperationData_M_fundCode_S': 'GB00BLD0TQ22',
#   'confirmation_M_generalOperationData_M_price_N': '16.9734',
#   'confirmation_M_generalOperationData_M_ccv_S': '',
#   'confirmation_M_generalOperationData_M_allFundsFundCode_S': '0289628',
#   'confirmation_M_generalOperationData_M_sourceContract_S': '46AA703B5FBEC9ECF030',
#   'confirmation_M_generalOperationData_M_fundIdentificationType_S': '00',
#   'confirmation_M_generalOperationData_M_subdistributor_S': '99999',
#   'confirmation_M_generalOperationData_M_settlementDate_S': '2023-03-13',
#   'confirmation_M_generalOperationData_M_operationNumber2_S': '',
#   'confirmation_M_generalOperationData_M_fundManagerSettlementDate_S': '2023-03-13',
#   'confirmation_M_generalOperationData_M_sequence_S': '0000000',
#   'confirmation_M_generalOperationData_M_dataTime_S': '201235',
#   'confirmation_M_generalOperationData_M_distributorCommission2_N': '0',
#   'confirmation_M_generalOperationData_M_amountToBeSettled_N': '5.02',
#   'confirmation_M_generalOperationData_M_deposit_N': '0',
#   'confirmation_M_generalOperationData_M_operationType_S': '20',
#   'confirmation_M_generalOperationData_M_fundName_S': 'OASIS CRESCENT GLOBAL "B" (GBP) D',
#   'confirmation_M_generalOperationData_M_paymentCurrency_S': 'GBP',
#   'confirmation_M_generalOperationData_M_confirmedShares_N': '0.296',
#   'confirmation_M_generalOperationData_M_operationDate_S': '2023-03-05',
#   'confirmation_M_generalOperationData_M_distributorCode_S': '00000',
#   'confirmation_M_generalOperationData_M_distributorCommission1_N': '0',
#   'confirmation_M_generalOperationData_M_switchFixing_N': '1',
#   'confirmation_M_generalOperationData_M_operationNumber_S': 'B8DBA6DD78CA76C6B',
#   'confirmation_M_generalOperationData_M_currency_S': 'GBP',
#   'confirmation_M_generalOperationData_M_corporateActionId_S': '',
#   'confirmation_M_generalOperationData_M_allFundsOperationNumber2_S': '0000000000000',
#   'confirmation_M_generalOperationData_M_product_S': '0000000035862',
#   'confirmation_M_generalOperationData_M_dataDate_S': '2023-03-07',
#   'confirmation_M_generalOperationData_M_entityCode_S': '14146',
#   'confirmation_M_generalOperationData_M_navDate_S': '2023-03-06',
#   'confirmation_M_generalOperationData_M_allFundsOperationNumber_S': '0000000000030',
#   'confirmation_M_generalOperationData_M_agreedFixingCurrency_S': 'GBP',
#   'confirmation_M_generalOperationData_M_recordSubtype_S': '01',
#   'confirmation_M_generalOperationData_M_recordType_S': '24',
#   'confirmation_M_generalOperationData_M_calculatedNetAmount_N': '5.02',
#   'confirmation_M_generalOperationData_M_counterValue_N': '0.8863',
#   'confirmation_M_generalOperationData_M_allFundsContract_S': '0000002',
#   'confirmation_M_generalOperationData_M_fundHouseCommission_N': '0',
#   'confirmation_M_generalOperationData_M_totalExchangeRate_N': '1',
#   'confirmation_M_generalOperationData_M_exchangeIndicator_S': 'N',
#   'confirmation_M_generalOperationData_M_fundCommission_N': '0',
#   'confirmation_M_generalOperationData_M_primaryKey_S': '24141460000000000030',
#   'amount_M_value_N': '5.02',
#   'amount_M_currency_S': 'GBP',
#   'provider_S': 'allFunds',
#   'providerInvestmentId_S': '289628',
#   'id_S': '9fb45f80-a4c9-4c98-940c-3c2152671801',
#   'traceId_S': 'deec6923-27ca-4aa9-9c29-7c7109ff1096',
#   'shares_N': '0.296'},
#  {'providerAccountId_S': '3',
#   'orderId_S': '19D82E1693EA83D28',
#   'status_S': 'AwaitingSettlement',
#   'tenantId_S': 'nomo',
#   'settlementCurrency_S': 'GBP',
#   'settlementDate_S': '2024-10-09',
#   'settlementShares_N': '1.503',
#   'confirmedAt_S': '2024-10-03T19:38:21.340Z',
#   'investmentName_S': 'OASIS CRESCENT GLOBAL MEDIUM EQUITY "D" (GBP) INC',
#   'pricePerShareOnSell_M_value_N': '17.2115',
#   'pricePerShareOnSell_M_currency_S': 'GBP',
#   'providerSellId_S': '134',
#   'userId_S': '4Cy2MnsdwWWWxbobzaPHPn',
#   'confirmation_M_generalOperationData_M_confirmationDate_S': '2024-10-03',
#   'confirmation_M_generalOperationData_M_ccc_S': '',
#   'confirmation_M_generalOperationData_M_calculatedCrossAmount_N': '25.89',
#   'confirmation_M_generalOperationData_M_secondaryKey_S': '0100000001',
#   'confirmation_M_generalOperationData_M_allFundsHouseCommission_N': '0',
#   'confirmation_M_generalOperationData_M_portfolioIndicator_S': 'N',
#   'confirmation_M_generalOperationData_M_performanceFee_N': '0',
#   'confirmation_M_generalOperationData_M_fundCode_S': 'GB00BLD0V662',
#   'confirmation_M_generalOperationData_M_cutOffDate_S': '2024-10-02',
#   'confirmation_M_generalOperationData_M_price_N': '17.2257',
#   'confirmation_M_generalOperationData_M_ccv_S': '',
#   'confirmation_M_generalOperationData_M_allFundsFundCode_S': '0289627',
#   'confirmation_M_generalOperationData_M_sourceContract_S': '4D7D092DD12227E77827',
#   'confirmation_M_generalOperationData_M_fundIdentificationType_S': '00',
#   'confirmation_M_generalOperationData_M_subdistributor_S': '99999',
#   'confirmation_M_generalOperationData_M_settlementDate_S': '2024-10-09',
#   'confirmation_M_generalOperationData_M_operationNumber2_S': '',
#   'confirmation_M_generalOperationData_M_fundManagerSettlementDate_S': '2024-10-09',
#   'confirmation_M_generalOperationData_M_sequence_S': '0000000',
#   'confirmation_M_generalOperationData_M_dataTime_S': '211354',
#   'confirmation_M_generalOperationData_M_distributorCommission2_N': '0',
#   'confirmation_M_generalOperationData_M_amountToBeSettled_N': '25.89',
#   'confirmation_M_generalOperationData_M_deposit_N': '0',
#   'confirmation_M_generalOperationData_M_operationType_S': '20',
#   'confirmation_M_generalOperationData_M_fundName_S': 'OASIS CRESCENT GLOBAL "D" (GBP) D A',
#   'confirmation_M_generalOperationData_M_paymentCurrency_S': 'GBP',
#   'confirmation_M_generalOperationData_M_confirmedShares_N': '1.503',
#   'confirmation_M_generalOperationData_M_operationDate_S': '2024-10-01',
#   'confirmation_M_generalOperationData_M_distributorCode_S': '00000',
#   'confirmation_M_generalOperationData_M_distributorCommission1_N': '0',
#   'confirmation_M_generalOperationData_M_switchFixing_N': '1',
#   'confirmation_M_generalOperationData_M_operationNumber_S': '19D82E1693EA83D28',
#   'confirmation_M_generalOperationData_M_currency_S': 'GBP',
#   'confirmation_M_generalOperationData_M_corporateActionId_S': '',
#   'confirmation_M_generalOperationData_M_allFundsOperationNumber2_S': '0000000000000',
#   'confirmation_M_generalOperationData_M_product_S': '0000000035862',
#   'confirmation_M_generalOperationData_M_entityCode_S': '14146',
#   'confirmation_M_generalOperationData_M_dataDate_S': '2024-10-03',
#   'confirmation_M_generalOperationData_M_navDate_S': '2024-10-02',
#   'confirmation_M_generalOperationData_M_allFundsOperationNumber_S': '0000000000134',
#   'confirmation_M_generalOperationData_M_recordType_S': '24',
#   'confirmation_M_generalOperationData_M_recordSubtype_S': '01',
#   'confirmation_M_generalOperationData_M_agreedFixingCurrency_S': 'GBP',
#   'confirmation_M_generalOperationData_M_calculatedNetAmount_N': '25.89',
#   'confirmation_M_generalOperationData_M_counterValue_N': '0.83287999',
#   'confirmation_M_generalOperationData_M_allFundsContract_S': '0000003',
#   'confirmation_M_generalOperationData_M_fundHouseCommission_N': '0',
#   'confirmation_M_generalOperationData_M_totalExchangeRate_N': '1',
#   'confirmation_M_generalOperationData_M_fundCommission_N': '0',
#   'confirmation_M_generalOperationData_M_exchangeIndicator_S': 'N',
#   'confirmation_M_generalOperationData_M_primaryKey_S': '24141460000000000134',
#   'provider_S': 'allFunds',
#   'providerInvestmentId_S': '289627',
#   'id_S': '66ef1970-5cdb-4127-ab43-f7c16c0198a2',
#   'traceId_S': '104817c3-3ddf-488b-8de8-7ddf397b7e92',
#   'encodedKey_S': '8a5e09827984889d017984889e9a0009',
#   'expectedSettlementDate_S': '2024-10-11T17:02:28.465Z',
#   'orderedAt_S': '2024-10-01T17:02:28.465Z',
#   'settlementAmount_N': '25.89',
#   'trace_L_0_M_createdAt_S': '2024-10-01T17:02:28.465Z',
#   'trace_L_0_M_status_S': 'PlaceOrderCreated',
#   'trace_L_1_M_createdAt_S': '2024-10-01T17:02:29.377Z',
#   'trace_L_1_M_status_S': 'AllFundsAccountCreated',
#   'trace_L_2_M_createdAt_S': '2024-10-01T17:02:30.626Z',
#   'trace_L_2_M_status_S': 'PlaceOrderSuccess',
#   'trace_L_3_M_createdAt_S': '2024-10-01T17:02:31.165Z',
#   'trace_L_3_M_status_S': 'AwaitingOrderConfirmation',
#   'trace_L_4_M_createdAt_S': '2024-10-03T19:38:21.340Z',
#   'trace_L_4_M_status_S': 'OrderConfirmed',
#   'trace_L_5_M_createdAt_S': '2024-10-03T19:38:22.421Z',
#   'trace_L_5_M_status_S': 'AwaitingSettlement',
#   'createdAt_N': '1727802148467',
#   'updatedAt_N': '1727984302440',
#   'amount_M_value_N': '0',
#   'amount_M_currency_S': 'GBP',
#   'shares_N': '1.503'},
#  {'providerAccountId_S': '2',
#   'orderId_S': 'E7B740879F409EF79',
#   'status_S': 'AwaitingSettlement',
#   'tenantId_S': 'nomo',
#   'settlementCurrency_S': 'USD',
#   'settlementDate_S': '2023-05-05',
#   'settlementShares_N': '0.01',
#   'confirmedAt_S': '2023-05-03T19:14:35.507Z',
#   'investmentName_S': 'BNP PARIBAS ISLAMIC FUND HILAL INCOME "C" (USD) ACC',
#   'pricePerShareOnSell_M_value_N': '1570',
#   'pricePerShareOnSell_M_currency_S': 'GBP',
#   'providerSellId_S': '41',
#   'userId_S': 'w1bzb16fXndSPP1iKMDJNc',
#   'confirmation_M_generalOperationData_M_confirmationDate_S': '2023-05-03',
#   'confirmation_M_generalOperationData_M_ccc_S': '',
#   'confirmation_M_generalOperationData_M_calculatedCrossAmount_N': '15.68',
#   'confirmation_M_generalOperationData_M_secondaryKey_S': '0100000001',
#   'confirmation_M_generalOperationData_M_allFundsHouseCommission_N': '0',
#   'confirmation_M_generalOperationData_M_portfolioIndicator_S': 'N',
#   'confirmation_M_generalOperationData_M_performanceFee_N': '0',
#   'confirmation_M_generalOperationData_M_fundCode_S': 'LU1150255971',
#   'confirmation_M_generalOperationData_M_cutOffDate_S': '2023-04-28',
#   'confirmation_M_generalOperationData_M_price_N': '1567.7417',
#   'confirmation_M_generalOperationData_M_ccv_S': '',
#   'confirmation_M_generalOperationData_M_allFundsFundCode_S': '0271544',
#   'confirmation_M_generalOperationData_M_sourceContract_S': '46AA703B5FBEC9ECF030',
#   'confirmation_M_generalOperationData_M_fundIdentificationType_S': '00',
#   'confirmation_M_generalOperationData_M_subdistributor_S': '99999',
#   'confirmation_M_generalOperationData_M_settlementDate_S': '2023-05-05',
#   'confirmation_M_generalOperationData_M_operationNumber2_S': '',
#   'confirmation_M_generalOperationData_M_fundManagerSettlementDate_S': '2023-05-05',
#   'confirmation_M_generalOperationData_M_sequence_S': '0000000',
#   'confirmation_M_generalOperationData_M_dataTime_S': '203721',
#   'confirmation_M_generalOperationData_M_distributorCommission2_N': '0',
#   'confirmation_M_generalOperationData_M_amountToBeSettled_N': '15.68',
#   'confirmation_M_generalOperationData_M_deposit_N': '0',
#   'confirmation_M_generalOperationData_M_operationType_S': '20',
#   'confirmation_M_generalOperationData_M_fundName_S': 'BNP PARIBAS ISLAMIC F HILAL INC "C"(USD)',
#   'confirmation_M_generalOperationData_M_paymentCurrency_S': 'USD',
#   'confirmation_M_generalOperationData_M_confirmedShares_N': '0.01',
#   'confirmation_M_generalOperationData_M_operationDate_S': '2023-04-27',
#   'confirmation_M_generalOperationData_M_distributorCode_S': '00000',
#   'confirmation_M_generalOperationData_M_distributorCommission1_N': '0',
#   'confirmation_M_generalOperationData_M_switchFixing_N': '1',
#   'confirmation_M_generalOperationData_M_operationNumber_S': 'E7B740879F409EF79',
#   'confirmation_M_generalOperationData_M_currency_S': 'USD',
#   'confirmation_M_generalOperationData_M_corporateActionId_S': '',
#   'confirmation_M_generalOperationData_M_allFundsOperationNumber2_S': '0000000000000',
#   'confirmation_M_generalOperationData_M_product_S': '0000000035862',
#   'confirmation_M_generalOperationData_M_entityCode_S': '14146',
#   'confirmation_M_generalOperationData_M_dataDate_S': '2023-05-03',
#   'confirmation_M_generalOperationData_M_navDate_S': '2023-05-02',
#   'confirmation_M_generalOperationData_M_allFundsOperationNumber_S': '0000000000041',
#   'confirmation_M_generalOperationData_M_recordType_S': '24',
#   'confirmation_M_generalOperationData_M_recordSubtype_S': '01',
#   'confirmation_M_generalOperationData_M_agreedFixingCurrency_S': 'USD',
#   'confirmation_M_generalOperationData_M_calculatedNetAmount_N': '15.68',
#   'confirmation_M_generalOperationData_M_counterValue_N': '1.0965',
#   'confirmation_M_generalOperationData_M_allFundsContract_S': '0000002',
#   'confirmation_M_generalOperationData_M_fundHouseCommission_N': '0',
#   'confirmation_M_generalOperationData_M_totalExchangeRate_N': '1',
#   'confirmation_M_generalOperationData_M_fundCommission_N': '0',
#   'confirmation_M_generalOperationData_M_exchangeIndicator_S': 'N',
#   'confirmation_M_generalOperationData_M_primaryKey_S': '24141460000000000041',
#   'provider_S': 'allFunds',
#   'providerInvestmentId_S': '271544',
#   'id_S': '0fb710e3-2ddd-492e-8918-410e8da5b235',
#   'traceId_S': 'SELL-USD-23-04-27',
#   'encodedKey_S': '8a5e2d14836856a4018369873b2802e0',
#   'expectedSettlementDate_S': '2023-05-07T14:21:33.069Z',
#   'orderedAt_S': '2023-04-27T14:21:33.068Z',
#   'settlementAmount_N': '15.68',
#   'trace_L_0_S': 'PlaceOrderCreated',
#   'trace_L_1_S': 'AllFundsAccountCreated',
#   'trace_L_2_S': 'PlaceOrderSuccess',
#   'trace_L_3_S': 'AwaitingOrderConfirmation',
#   'trace_L_4_S': 'OrderConfirmed',
#   'trace_L_5_S': 'AwaitingSettlement',
#   'createdAt_N': '1682605293071',
#   'updatedAt_N': '1683141276163',
#   'amount_M_value_N': '0',
#   'amount_M_currency_S': 'GBP',
#   'shares_N': '0.01'}]

# %%
final_df = pd.DataFrame(frames)

# %%
final_df.columns
# Out:
# Index(['encodedKey_S', 'providerAccountId_S', 'expectedSettlementDate_S',
#        'orderedAt_S', 'orderId_S', 'status_S', 'tenantId_S', 'trace_L_0_S',
#        'trace_L_1_S', 'trace_L_2_S', 'trace_L_3_S', 'createdAt_N',
#        'pricePerShareOnSell_M_value_N', 'pricePerShareOnSell_M_currency_S',
#        'providerSellId_S', 'updatedAt_N', 'userId_S', 'amount_M_value_N',
#        'amount_M_currency_S', 'provider_S', 'providerInvestmentId_S', 'id_S',
#        'traceId_S', 'shares_N', 'settlementDate_S', 'settlementShares_N',
#        'trace_L_0_M_createdAt_S', 'trace_L_0_M_status_S',
#        'trace_L_1_M_createdAt_S', 'trace_L_1_M_status_S',
#        'trace_L_2_M_createdAt_S', 'trace_L_2_M_status_S',
#        'trace_L_3_M_createdAt_S', 'trace_L_3_M_status_S', 'investmentName_S',
#        'settlementCurrency_S', 'confirmedAt_S',
#        'confirmation_M_generalOperationData_M_confirmationDate_S',
#        'confirmation_M_generalOperationData_M_ccc_S',
#        'confirmation_M_generalOperationData_M_calculatedCrossAmount_N',
#        'confirmation_M_generalOperationData_M_secondaryKey_S',
#        'confirmation_M_generalOperationData_M_allFundsHouseCommission_N',
#        'confirmation_M_generalOperationData_M_portfolioIndicator_S',
#        'confirmation_M_generalOperationData_M_performanceFee_N',
#        'confirmation_M_generalOperationData_M_fundCode_S',
#        'confirmation_M_generalOperationData_M_cutOffDate_S',
#        'confirmation_M_generalOperationData_M_price_N',
#        'confirmation_M_generalOperationData_M_ccv_S',
#        'confirmation_M_generalOperationData_M_allFundsFundCode_S',
#        'confirmation_M_generalOperationData_M_sourceContract_S',
#        'confirmation_M_generalOperationData_M_fundIdentificationType_S',
#        'confirmation_M_generalOperationData_M_subdistributor_S',
#        'confirmation_M_generalOperationData_M_settlementDate_S',
#        'confirmation_M_generalOperationData_M_operationNumber2_S',
#        'confirmation_M_generalOperationData_M_fundManagerSettlementDate_S',
#        'confirmation_M_generalOperationData_M_sequence_S',
#        'confirmation_M_generalOperationData_M_dataTime_S',
#        'confirmation_M_generalOperationData_M_distributorCommission2_N',
#        'confirmation_M_generalOperationData_M_amountToBeSettled_N',
#        'confirmation_M_generalOperationData_M_deposit_N',
#        'confirmation_M_generalOperationData_M_operationType_S',
#        'confirmation_M_generalOperationData_M_fundName_S',
#        'confirmation_M_generalOperationData_M_paymentCurrency_S',
#        'confirmation_M_generalOperationData_M_confirmedShares_N',
#        'confirmation_M_generalOperationData_M_operationDate_S',
#        'confirmation_M_generalOperationData_M_distributorCode_S',
#        'confirmation_M_generalOperationData_M_distributorCommission1_N',
#        'confirmation_M_generalOperationData_M_switchFixing_N',
#        'confirmation_M_generalOperationData_M_operationNumber_S',
#        'confirmation_M_generalOperationData_M_currency_S',
#        'confirmation_M_generalOperationData_M_corporateActionId_S',
#        'confirmation_M_generalOperationData_M_allFundsOperationNumber2_S',
#        'confirmation_M_generalOperationData_M_product_S',
#        'confirmation_M_generalOperationData_M_entityCode_S',
#        'confirmation_M_generalOperationData_M_dataDate_S',
#        'confirmation_M_generalOperationData_M_navDate_S',
#        'confirmation_M_generalOperationData_M_allFundsOperationNumber_S',
#        'confirmation_M_generalOperationData_M_recordType_S',
#        'confirmation_M_generalOperationData_M_recordSubtype_S',
#        'confirmation_M_generalOperationData_M_agreedFixingCurrency_S',
#        'confirmation_M_generalOperationData_M_calculatedNetAmount_N',
#        'confirmation_M_generalOperationData_M_counterValue_N',
#        'confirmation_M_generalOperationData_M_allFundsContract_S',
#        'confirmation_M_generalOperationData_M_fundHouseCommission_N',
#        'confirmation_M_generalOperationData_M_totalExchangeRate_N',
#        'confirmation_M_generalOperationData_M_fundCommission_N',
#        'confirmation_M_generalOperationData_M_exchangeIndicator_S',
#        'confirmation_M_generalOperationData_M_primaryKey_S',
#        'settlementAmount_N', 'trace_L_4_S', 'trace_L_5_S',
#        'trace_L_4_M_createdAt_S', 'trace_L_4_M_status_S',
#        'trace_L_5_M_createdAt_S', 'trace_L_5_M_status_S'],
#       dtype='object')

# %%
# get schema and dataframe for write to athena
athena_schema = get_actual_dtypes(final_df)

# %%
athena_schema
# Out:
# {'encodedKey_S': 'string',
#  'providerAccountId_S': 'int',
#  'expectedSettlementDate_S': 'timestamp',
#  'orderedAt_S': 'timestamp',
#  'orderId_S': 'string',
#  'status_S': 'string',
#  'tenantId_S': 'string',
#  'trace_L_0_S': 'string',
#  'trace_L_1_S': 'string',
#  'trace_L_2_S': 'string',
#  'trace_L_3_S': 'string',
#  'createdAt_N': 'bigint',
#  'pricePerShareOnSell_M_value_N': 'double',
#  'pricePerShareOnSell_M_currency_S': 'string',
#  'providerSellId_S': 'int',
#  'updatedAt_N': 'string',
#  'userId_S': 'string',
#  'amount_M_value_N': 'double',
#  'amount_M_currency_S': 'string',
#  'provider_S': 'string',
#  'providerInvestmentId_S': 'int',
#  'id_S': 'string',
#  'traceId_S': 'string',
#  'shares_N': 'double',
#  'settlementDate_S': 'string',
#  'settlementShares_N': 'double',
#  'trace_L_0_M_createdAt_S': 'timestamp',
#  'trace_L_0_M_status_S': 'string',
#  'trace_L_1_M_createdAt_S': 'timestamp',
#  'trace_L_1_M_status_S': 'string',
#  'trace_L_2_M_createdAt_S': 'timestamp',
#  'trace_L_2_M_status_S': 'string',
#  'trace_L_3_M_createdAt_S': 'timestamp',
#  'trace_L_3_M_status_S': 'string',
#  'investmentName_S': 'string',
#  'settlementCurrency_S': 'string',
#  'confirmedAt_S': 'timestamp',
#  'confirmation_M_generalOperationData_M_confirmationDate_S': 'date',
#  'confirmation_M_generalOperationData_M_ccc_S': 'string',
#  'confirmation_M_generalOperationData_M_calculatedCrossAmount_N': 'double',
#  'confirmation_M_generalOperationData_M_secondaryKey_S': 'string',
#  'confirmation_M_generalOperationData_M_allFundsHouseCommission_N': 'int',
#  'confirmation_M_generalOperationData_M_portfolioIndicator_S': 'string',
#  'confirmation_M_generalOperationData_M_performanceFee_N': 'int',
#  'confirmation_M_generalOperationData_M_fundCode_S': 'string',
#  'confirmation_M_generalOperationData_M_cutOffDate_S': 'date',
#  'confirmation_M_generalOperationData_M_price_N': 'double',
#  'confirmation_M_generalOperationData_M_ccv_S': 'string',
#  'confirmation_M_generalOperationData_M_allFundsFundCode_S': 'string',
#  'confirmation_M_generalOperationData_M_sourceContract_S': 'string',
#  'confirmation_M_generalOperationData_M_fundIdentificationType_S': 'int',
#  'confirmation_M_generalOperationData_M_subdistributor_S': 'int',
#  'confirmation_M_generalOperationData_M_settlementDate_S': 'date',
#  'confirmation_M_generalOperationData_M_operationNumber2_S': 'string',
#  'confirmation_M_generalOperationData_M_fundManagerSettlementDate_S': 'date',
#  'confirmation_M_generalOperationData_M_sequence_S': 'int',
#  'confirmation_M_generalOperationData_M_dataTime_S': 'int',
#  'confirmation_M_generalOperationData_M_distributorCommission2_N': 'int',
#  'confirmation_M_generalOperationData_M_amountToBeSettled_N': 'double',
#  'confirmation_M_generalOperationData_M_deposit_N': 'int',
#  'confirmation_M_generalOperationData_M_operationType_S': 'int',
#  'confirmation_M_generalOperationData_M_fundName_S': 'string',
#  'confirmation_M_generalOperationData_M_paymentCurrency_S': 'string',
#  'confirmation_M_generalOperationData_M_confirmedShares_N': 'double',
#  'confirmation_M_generalOperationData_M_operationDate_S': 'date',
#  'confirmation_M_generalOperationData_M_distributorCode_S': 'int',
#  'confirmation_M_generalOperationData_M_distributorCommission1_N': 'int',
#  'confirmation_M_generalOperationData_M_switchFixing_N': 'int',
#  'confirmation_M_generalOperationData_M_operationNumber_S': 'string',
#  'confirmation_M_generalOperationData_M_currency_S': 'string',
#  'confirmation_M_generalOperationData_M_corporateActionId_S': 'string',
#  'confirmation_M_generalOperationData_M_allFundsOperationNumber2_S': 'int',
#  'confirmation_M_generalOperationData_M_product_S': 'string',
#  'confirmation_M_generalOperationData_M_entityCode_S': 'int',
#  'confirmation_M_generalOperationData_M_dataDate_S': 'date',
#  'confirmation_M_generalOperationData_M_navDate_S': 'date',
#  'confirmation_M_generalOperationData_M_allFundsOperationNumber_S': 'string',
#  'confirmation_M_generalOperationData_M_recordType_S': 'int',
#  'confirmation_M_generalOperationData_M_recordSubtype_S': 'string',
#  'confirmation_M_generalOperationData_M_agreedFixingCurrency_S': 'string',
#  'confirmation_M_generalOperationData_M_calculatedNetAmount_N': 'double',
#  'confirmation_M_generalOperationData_M_counterValue_N': 'double',
#  'confirmation_M_generalOperationData_M_allFundsContract_S': 'string',
#  'confirmation_M_generalOperationData_M_fundHouseCommission_N': 'int',
#  'confirmation_M_generalOperationData_M_totalExchangeRate_N': 'int',
#  'confirmation_M_generalOperationData_M_fundCommission_N': 'int',
#  'confirmation_M_generalOperationData_M_exchangeIndicator_S': 'string',
#  'confirmation_M_generalOperationData_M_primaryKey_S': 'string',
#  'settlementAmount_N': 'double',
#  'trace_L_4_S': 'string',
#  'trace_L_5_S': 'string',
#  'trace_L_4_M_createdAt_S': 'timestamp',
#  'trace_L_4_M_status_S': 'string',
#  'trace_L_5_M_createdAt_S': 'timestamp',
#  'trace_L_5_M_status_S': 'string'}
